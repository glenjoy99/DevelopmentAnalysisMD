# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as plticker

# %%
data = pd.read_csv("./Maryland_Total_New_Housing_Units_Authorized_For_Construction__2000-2017.csv")

# %%
data = data.set_index(data.Year)

# %%
data = data.sort_index(0, ascending=True)
housingPG = data[data.columns[19]]
housingMO = data[data.columns[18]]
data.head()
# Out:
#                  Date created  Year  MARYLAND  Allegany County  \
# Year
# 2000  2018-08-02T00:00:00.000  2000     30358               79
# 2001  2018-08-02T00:00:00.000  2001     29059               80
# 2002  2018-08-02T00:00:00.000  2002     29293              103
# 2003  2018-08-02T00:00:00.000  2003     29914              107
# 2004  2018-08-02T00:00:00.000  2004     27382              120
#
#       Anne Arundel County  Baltimore City  Baltimore County  Calvert County  \
# Year
# 2000                 3078             257              2707             931
# 2001                 2492             195              3153             886
# 2002                 2359             293              2706             928
# 2003                 3001             695              2599             791
# 2004                 2364             740              2103             525
#
#       Caroline County  Carroll County        ...         Kent County  \
# ...

# %%
ax = plt.gca()
# plt.plot(data.Year, data[data.columns[3::]])
plt.plot(data.Year, housingPG, housingMO)
plt.title("Approved Housing Construction in PG and MoCo")
for label in ax.xaxis.get_ticklabels():
    label.set_rotation(30)
    
loc = plticker.MultipleLocator(base=1.0)
ax.xaxis.set_major_locator(loc)
fig = plt.gcf()
fig.set_size_inches(11,8)
plt.ylabel("Approved Housing Units")
plt.xlabel("Year")
plt.legend()
plt.show
# Out:
# No handles with labels found to put in legend.
# <function matplotlib.pyplot.show(*args, **kw)>
